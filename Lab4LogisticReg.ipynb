# %% [markdown]
# <a href="https://colab.research.google.com/github/toche7/AI_ITM/blob/main/Lab4LogisticReg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 4: Logistic Regression Model

# %% [markdown]
# ### Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://github.com/toche7/DataSets/raw/main/apple.csv")

# %%
df.head()

# %%
import seaborn as sns

# %%
sns.pairplot(df)

# %% [markdown]
# ### Data Preparation

# %%
X = df[['Weight','Size']]
X.head()

# %%
y = df[['Class']]
y.head()

# %% [markdown]
# ### Create Model

# %%
from sklearn.linear_model import LogisticRegression

# %%
lgModel = LogisticRegression()

# %% [markdown]
# ### Train Model

# %%
lgModel.fit(X,y)

# %% [markdown]
# ### Evaluation

# %%
lgModel.score(X,y)

# %% [markdown]
# ### Prediction

# %%
lgModel.predict(X)

# %%
t1 = [[70,4.3]]
t1

# %%
lgModel.predict(t1)

# %%
t = [[70,4.3],[68,5.6]]

# %%
lgModel.predict(t)
