# %% [markdown]
# <a href="https://colab.research.google.com/github/toche7/AI_ITM/blob/main/Ex1LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 1: Linear Regression

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('https://github.com/toche7/DataSets/raw/main/sale.txt', header = None, sep = ',')

# %%
df.columns = ['pop','sale']

# %%
df
# Out:
#         pop      sale
# 0    6.1101  17.59200
# 1    5.5277   9.13020
# 2    8.5186  13.66200
# 3    7.0032  11.85400
# 4    5.8598   6.82330
# ..      ...       ...
# 92   5.8707   7.20290
# 93   5.3054   1.98690
# 94   8.2934   0.14454
# 95  13.3940   9.05510
# 96   5.4369   0.61705
#
# [97 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['pop'].plot(kind='hist', bins=20, title='pop')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['sale'].plot(kind='hist', bins=20, title='sale')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
X = df[['pop']]
X.head()
# Out:
#       pop
# 0  6.1101
# 1  5.5277
# 2  8.5186
# 3  7.0032
# 4  5.8598

# %%
y = df[['sale']]
y.tail()
# Out:
#        sale
# 92  7.20290
# 93  1.98690
# 94  0.14454
# 95  9.05510
# 96  0.61705

# %%
from sklearn.linear_model import LinearRegression

regModel = LinearRegression()

# %%
regModel.fit(X,y)
# Out:
# LinearRegression()

# %%
regModel.score(X,y)
# Out:
# 0.7020315537841397

# %%
yhat = regModel.predict(X)
yhat
# Out:
# array([[ 3.39377399],
#        [ 2.6989512 ],
#        [ 6.26719552],
#        [ 4.45927234],
#        [ 3.09515767],
#        [ 6.10530086],
#        [ 5.02381586],
#        [ 6.33818102],
#        [ 3.84247394],
#        [ 2.13452698],
#        [ 2.91727635],
#        [13.00234766],
#        [ 2.94507404],
#        [ 6.13572322],
#        [ 2.833764  ],
#        [ 2.52202431],
#        [ 3.69835548],
#        [ 2.22460102],
#        [ 3.77494824],
#        [ 4.53992141],
#        [ 3.48802365],
#        [20.28701109],
#        [ 2.65409313],
#        [ 3.65146926],
#        [ 2.74333205],
#        [18.70624151],
#        [11.40845471],
#        [ 9.17628876],
#        [11.82363042],
#        [22.59314512],
#        [ 2.37050903],
#        [ 3.96559502],
#        [ 7.13763287],
#        [ 3.13333475],
#        [ 5.90033768],
#        [ 5.56903223],
#        [ 5.7629002 ],
#        [ 2.79272364],
#        [11.41799898],
#        [ 3.68403908],
#        [ 2.55483273],
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(X,y,'*')
plt.plot(X,yhat,'^')
