# %% [markdown]
# <a href="https://colab.research.google.com/github/toche7/AI_ITM/blob/main/Lab6EvaluaitonMartix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Lab 6. Evaluation Matrix for Classification Models.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/toche7/DataSets/main/admit.csv')
df.head()

# %%
import seaborn as sns

# %%
sns.pairplot(df, hue='Label')

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ## Precision, Recall and F-Score

# %%
from sklearn.metrics import precision_recall_fscore_support as score
